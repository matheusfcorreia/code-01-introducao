# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusfcorreia/code-01-introducao/blob/master/Copy_of_code_01_Introdu%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercício
#
# Olá! Vamos praticar alguns comandos através de exercícios _hands on_.

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import array
from PIL import Image

# %% [markdown]
# Procurem três tipos de imagens:
#
# *   Uma imagem preto e branco;
# *   Uma imagem em tons de cinza;
# *   Uma imagem colorida, de extensão `jpg`.
#
# Salvem as imagens no GoogleDrive, e carreguem no script. Crie as seguintes variáveis: `imagem_pb`, `imagem_cinza` e `imagem_color`, carregue e "plote" as duas imagens.

# %%
# escreva o código aqui
path = '/content/drive/My Drive/'

imagem_pb = Image.open(path + 'preto-branco.jpg')
imagem_cinza = Image.open(path + 'tons-cinza.jpg')
imagem_color = Image.open(path + 'colorida.jpg')

plt.subplot(131)
plt.axis('off')
plt.imshow(imagem_pb)

plt.subplot(132) 
plt.axis('off')
plt.imshow(imagem_cinza)

plt.subplot(133) 
plt.axis('off')
plt.imshow(imagem_color)

plt.show()

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Realize uma análise exploratória dos dados das imagens, e responda as questões abaixo:

# %%
# escreva os códigos necessários para análise aqui, inclua pontos de códigos entre
# as questões, assim como incluam plots, tabelas, o que for necessário 
blackImgArr = np.array(imagem_pb)
greyImgArr = np.array(imagem_cinza)
colorImgArr = np.array(imagem_color)

# blackImgArr.shape
# colorImgArr[:, :, 1] 
# blackImgArr.max()
# blackImgArr.min()
# blackImgArr.mean()

# greyImgArr.max()
# greyImgArr.min()
# greyImgArr.mean()




# colorImgArr[:,:,(1,2)] = 0
# plt.subplot(111) 
# plt.axis('off')
# plt.imshow(colorImgArr)
# colorImgArr.max()
# colorImgArr.min()

red = colorImgArr[:,:,0] 
# plt.subplot(111) 
# plt.axis('off')
# red.max()
# red.min()
# red.mean()

green = colorImgArr[:,:,1] 
# plt.subplot(111) 
# plt.axis('off')
# green.max()
# green.min()
# green.mean()

blue = colorImgArr[:,:,2] 
# plt.subplot(111) 
# plt.axis('off')
# blue.max()
# blue.min()
# blue.mean()


# plt.show()

# %% [markdown]
# Qual o menor e maior valor das imagens:
#
# *   [pb]: 0 e 255;
# *   [cinza]: 0 e 255;
# *   [color]:
#     * [R]: 8 e 255
#     * [G]: 0 e 255
#     * [B]: 0 e 255

# %% [markdown]
# Qual o valor da média imagens:
#
# *   [pb]: 115
# *   [cinza]: 129
# *   [color]:
#     * [R] 199
#     * [G] 176
#     * [B] 168

# %% [markdown]
# Qual o valor da mediana imagens:
#
# *   [pb]:
# *   [cinza]:
# *   [color]:
#     * [R]
#     * [G]
#     * [B]

# %% [markdown]
# Inverta os valores de `imagem_pb`, e "plote" a figura.

# %%
pb_red = blackImgArr[:,:,0]
pb_green = blackImgArr[:,:,1]
pb_blue = blackImgArr[:,:,2]

inv = ([pb_red, pb_green, pb_blue])
inv = np.reshape(inv, (2481, 3507, 3))

# pb_red.shape

plt.figure(figsize=(12,4))
plt.imshow(inv)

# %% [markdown]
# Faça a média entre os valores `R`, `G` e `B` de `image_color`, e gere uma nova imagem e plot o resultado.

# %%
color_media = (red + green + blue) / 3

plt.subplot(111) 
plt.axis('off')
plt.imshow(color_media)
